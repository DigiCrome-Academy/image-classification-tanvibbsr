# %% [markdown]
# # Phase 2 — Advanced Neural Network with Regularisation
#
# **Learning Goals**
# - Build a deeper network with the Keras Functional API
# - Apply Batch Normalization, Dropout, and L1/L2 regularisation
# - Implement gradient clipping to prevent exploding gradients
# - Use advanced callbacks (EarlyStopping, ReduceLROnPlateau)
#
# **Tasks to complete:**
# 1. `TODO 5` in `src/models.py` — `build_advanced_nn()`
# 2. `TODO 9` in `src/train.py` — `get_callbacks()` (if not done in Phase 1)
#
# Run `pytest tests/test_phase2.py -v` to check your work.

# %%
import sys
sys.path.insert(0, '..')

import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

from src.data_loader import get_data_generators, compute_class_weights
from src.train import get_callbacks, train_model, plot_history

# %%
train_gen, val_gen, test_gen = get_data_generators(
    data_dir='../data/chest_xray',
    img_size=(64, 64),
    batch_size=32,
)
class_weights = compute_class_weights(train_gen)
# Out:
# Found 2914 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.

# %% [markdown]
# ## 1. Build the Advanced Network
#
# Implement `build_advanced_nn()` in `src/models.py`.
#
# **Architecture checklist:**
# - [ ] Functional API (not Sequential)
# - [ ] BatchNormalization after every Dense layer
# - [ ] Dropout (experiment with rates 0.3, 0.4, 0.5)
# - [ ] L2 regularisation on kernel weights
# - [ ] Gradient clipping on the Adam optimizer

# %%
from src.models import build_advanced_nn

model = build_advanced_nn(
    input_shape=(64, 64, 3),
    dropout_rate=0.5,
    l2_lambda=1e-4,
    learning_rate=1e-3,
)
model.summary()
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 64, 64, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 12288)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │     6,291,968 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,459,905 (24.64 MB)
#  Trainable params: 6,458,113 (24.64 MB)
#  Non-trainable params: 1,792 (7.00 KB)

# %%
callbacks = get_callbacks(model_name='advanced_nn', patience=7)

history = train_model(
    model,
    train_gen,
    val_gen,
    epochs=30,
    class_weights=class_weights,
    callbacks=callbacks,
)
plot_history(history, title='Advanced NN')
# Out:
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# Cell In[4], line 3
#       1 callbacks = get_callbacks(model_name='advanced_nn', patience=7)
# ----> 3 history = train_model(
#       4     model,
#       5     train_gen,
#       6     val_gen,
#       7     epochs=30,
#       8     class_weights=class_weights,
#       9     callbacks=callbacks,
#      10 )
#      11 plot_history(history, title='Advanced NN')
#
# File c:\Users\jbisw\OneDrive - UNT System\Documents\ImageClass\image-classification-tanvibbsr\notebooks\..\src\train.py:152, in train_model(model, train_data, val_data, epochs, class_weights, callbacks)
#     132 """
#     133 Train `model` and return the History object.
#     134
#    (...)    149     keras.callbacks.History
#     150 """
#     151 # ── YOUR CODE STARTS HERE ─────────────────────────────────────────────
# --> 152 history = model.fit(
#     153     train_data,
#     154     validation_data=val_data,
#     155     epochs=epochs,
#     156     class_weight=class_weights,
#     157     callbacks=callbacks,
#     158 )
#     159 return history
#     160 raise NotImplementedError("TODO 11: implement train_model()")
#
# File c:\Users\jbisw\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File c:\Users\jbisw\AppData\Local\Programs\Python\Python313\Lib\site-packages\PIL\Image.py:3532, in open(fp, mode, formats)
#    3530     warnings.warn(message)
#    3531 msg = "cannot identify image file %r" % (filename if filename else fp)
# -> 3532 raise UnidentifiedImageError(msg)
#
# UnidentifiedImageError: cannot identify image file <_io.BytesIO object at 0x0000024BFFCD11C0>

# %% [markdown]
# ## 2. Regularisation Ablation Study
#
# Train three variants and compare:
# - No regularisation
# - L2 only
# - L2 + Dropout + BatchNorm (full)

# %%
from src.models import build_baseline_mlp

configs = {
    'No reg':   dict(dropout_rate=0.0, l2_lambda=0.0),
    'L2 only':  dict(dropout_rate=0.0, l2_lambda=1e-4),
    'Full reg': dict(dropout_rate=0.5, l2_lambda=1e-4),
}

ablation_results = {}
for name, cfg in configs.items():
    m = build_advanced_nn(input_shape=(64, 64, 3), **cfg)
    h = train_model(m, train_gen, val_gen, epochs=15, class_weights=class_weights)
    ablation_results[name] = {
        'val_acc': max(h.history['val_accuracy']),
        'val_loss': min(h.history['val_loss']),
    }
    print(f"{name}: val_acc={ablation_results[name]['val_acc']:.4f}")
# Out:
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# Cell In[5], line 12
#      10 for name, cfg in configs.items():
#      11     m = build_advanced_nn(input_shape=(64, 64, 3), **cfg)
# ---> 12     h = train_model(m, train_gen, val_gen, epochs=15, class_weights=class_weights)
#      13     ablation_results[name] = {
#      14         'val_acc': max(h.history['val_accuracy']),
#      15         'val_loss': min(h.history['val_loss']),
#      16     }
#      17     print(f"{name}: val_acc={ablation_results[name]['val_acc']:.4f}")
#
# File c:\Users\jbisw\OneDrive - UNT System\Documents\ImageClass\image-classification-tanvibbsr\notebooks\..\src\train.py:152, in train_model(model, train_data, val_data, epochs, class_weights, callbacks)
#     132 """
#     133 Train `model` and return the History object.
#     134
#    (...)    149     keras.callbacks.History
#     150 """
#     151 # ── YOUR CODE STARTS HERE ─────────────────────────────────────────────
# --> 152 history = model.fit(
#     153     train_data,
#     154     validation_data=val_data,
#     155     epochs=epochs,
#     156     class_weight=class_weights,
#     157     callbacks=callbacks,
#     158 )
#     159 return history
#     160 raise NotImplementedError("TODO 11: implement train_model()")
#
# File c:\Users\jbisw\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File c:\Users\jbisw\AppData\Local\Programs\Python\Python313\Lib\site-packages\PIL\Image.py:3532, in open(fp, mode, formats)
#    3530     warnings.warn(message)
#    3531 msg = "cannot identify image file %r" % (filename if filename else fp)
# -> 3532 raise UnidentifiedImageError(msg)
#
# UnidentifiedImageError: cannot identify image file <_io.BytesIO object at 0x0000024B963EF600>

# %% [markdown]
# ## 3. Visualise Training vs Validation Loss Gap
#
# A large gap indicates overfitting. Plot both runs side by side.

# %%
# TODO: train a model WITHOUT regularisation and one WITH full regularisation.
# Plot train loss vs val loss for each to visualise the overfitting gap.
# Use plot_history() from src.train.

train_no_reg = train_model(
    build_advanced_nn(input_shape=(64, 64, 3), dropout_rate=0.0, l2_lambda=0.0),
    train_gen,
    val_gen,
    epochs=30,
    class_weights=class_weights,
)
plot_history(train_no_reg, title='No Regularisation')
train_full_reg = train_model(
    build_advanced_nn(input_shape=(64, 64, 3), dropout_rate=0.5, l2_lambda=1e-4),
    train_gen,
    val_gen,
    epochs=30,
    class_weights=class_weights,
)
plot_history(train_full_reg, title='Full Regularisation')
# Out:
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# Cell In[6], line 5
#       1 # TODO: train a model WITHOUT regularisation and one WITH full regularisation.
#       2 # Plot train loss vs val loss for each to visualise the overfitting gap.
#       3 # Use plot_history() from src.train.
# ----> 5 train_no_reg = train_model(
#       6     build_advanced_nn(input_shape=(64, 64, 3), dropout_rate=0.0, l2_lambda=0.0),
#       7     train_gen,
#       8     val_gen,
#       9     epochs=30,
#      10     class_weights=class_weights,
#      11 )
#      12 plot_history(train_no_reg, title='No Regularisation')
#      13 train_full_reg = train_model(
#      14     build_advanced_nn(input_shape=(64, 64, 3), dropout_rate=0.5, l2_lambda=1e-4),
#      15     train_gen,
#    (...)     18     class_weights=class_weights,
#      19 )
#
# File c:\Users\jbisw\OneDrive - UNT System\Documents\ImageClass\image-classification-tanvibbsr\notebooks\..\src\train.py:152, in train_model(model, train_data, val_data, epochs, class_weights, callbacks)
#     132 """
#     133 Train `model` and return the History object.
#     134
#    (...)    149     keras.callbacks.History
#     150 """
#     151 # ── YOUR CODE STARTS HERE ─────────────────────────────────────────────
# --> 152 history = model.fit(
#     153     train_data,
#     154     validation_data=val_data,
#     155     epochs=epochs,
#     156     class_weight=class_weights,
#     157     callbacks=callbacks,
#     158 )
#     159 return history
#     160 raise NotImplementedError("TODO 11: implement train_model()")
#
# File c:\Users\jbisw\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File c:\Users\jbisw\AppData\Local\Programs\Python\Python313\Lib\site-packages\PIL\Image.py:3532, in open(fp, mode, formats)
#    3530     warnings.warn(message)
#    3531 msg = "cannot identify image file %r" % (filename if filename else fp)
# -> 3532 raise UnidentifiedImageError(msg)
#
# UnidentifiedImageError: cannot identify image file <_io.BytesIO object at 0x0000024B965A55D0>

# %% [markdown]
# ## 4. Reflection Questions
#
# 1. What is the vanishing gradient problem and how does Batch Normalization help?
# 2. Explain the difference between L1 and L2 regularisation. When would you prefer each?
# 3. How does Dropout prevent overfitting? What is its effect at inference time?
# 4. Why is gradient clipping important? What happens without it on deep networks?

# %% [markdown]
# **Your answers here:**
#
# 1.
# 2.
# 3.
# 4.
